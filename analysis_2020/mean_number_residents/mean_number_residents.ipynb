# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# carrega dataset 2020
df_enem_2020 = pd.read_csv('../../data/enem_2020.csv', on_bad_lines='skip', encoding='ISO-8859-1', delimiter=',')

# %% [markdown]
# ## Número de pessoas na residência na Pandemia
# ### Correlação entre o número de pessoas na mesma residência, situação socioeconômica e também estruturação familiar vcs media das notas no ENEM.
# #### Referencia:
# 1	-> 1, pois moro sozinho(a).
# 2	-> 2 pessoas
# 3	-> 3 pessoas
# 4	-> 4 pessoas
# 5	-> 5 pessoas
# 6	-> 6 pessoas
# 7	-> 7 pessoas
# 8	-> 8 pessoas
# 9	-> 9 pessoas
# 10	-> 10 pessoas
# 11	-> 11 pessoas
# 12	-> 12 pessoas
# 13	-> 13 pessoas
# 14	-> 14 pessoas
# 15	-> 15 pessoas
# 16	-> 16 pessoas
# 17	-> 17 pessoas
# 18	-> 18 pessoas
# 19	-> 19 pessoas
# 20	-> 20 pessoas

# %% [markdown]
# ### Comparando média de todas as notas:

# %%
# Calculando a média das notas das colunas
df_enem_2020['media_notas'] = df_enem_2020[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']].mean(axis=1)

#Correlação com número de pessoas na residência
sns.barplot(x='Q005', y='media_notas', data=df_enem_2020)

# %% [markdown]
# ### Comparando médias em Ciências da Natureza

# %%
# Correlação com número de pessoas na residência
sns.barplot(x='Q005', y='NU_NOTA_CN', data=df_enem_2020)
# Out:
# <Axes: xlabel='Q005', ylabel='NU_NOTA_CN'>

# %% [markdown]
# ### Comparando médias em Ciências Humanas

# %%
# Correlação com número de pessoas na residência
sns.barplot(x='Q005', y='NU_NOTA_CH', data=df_enem_2020)
# Out:
# <Axes: xlabel='Q005', ylabel='NU_NOTA_CH'>

# %% [markdown]
# ### Comparando médias em Linguagens e Códigos

# %%
# Correlação com número de pessoas na residência
sns.barplot(x='Q005', y='NU_NOTA_LC', data=df_enem_2020)
# Out:
# <Axes: xlabel='Q005', ylabel='NU_NOTA_LC'>

# %% [markdown]
# ### Comparando médias em Matemática

# %%
# Correlação com número de pessoas na residência
sns.barplot(x='Q005', y='NU_NOTA_MT', data=df_enem_2020)
# Out:
# <Axes: xlabel='Q005', ylabel='NU_NOTA_MT'>

# %% [markdown]
# ### Comparando médias em Redação

# %%
# Correlação com número de pessoas na residência
sns.barplot(x='Q005', y='NU_NOTA_REDACAO', data=df_enem_2020)
# Out:
# <Axes: xlabel='Q005', ylabel='NU_NOTA_REDACAO'>
